# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
train_df = pd.read_csv(r'D:\Projects\Human Activity Recognition\train.csv')
test_df = pd.read_csv(r'D:\Projects\Human Activity Recognition\test.csv')

# %%
print('Train dataset shape:',train_df.shape)
print('Test dataset shape:', test_df.shape)
# Out:
# Train dataset shape: (7352, 563)
# Test dataset shape: (2947, 563)

# %%
pd.set_option('display.max_columns', None)

# %%
train_df.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.288585          -0.020294          -0.132905         -0.995279
# 1           0.278419          -0.016411          -0.123520         -0.998245
# 2           0.279653          -0.019467          -0.113462         -0.995380
# 3           0.279174          -0.026201          -0.123283         -0.996091
# 4           0.276629          -0.016570          -0.115362         -0.998139
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.983111         -0.913526         -0.995112         -0.983185
# 1         -0.975300         -0.960322         -0.998807         -0.974914
# 2         -0.967187         -0.978944         -0.996520         -0.963668
# 3         -0.983403         -0.990675         -0.997099         -0.982750
# 4         -0.980817         -0.990482         -0.998321         -0.979672
#
# ...

# %%
test_df.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.257178          -0.023285          -0.014654         -0.938404
# 1           0.286027          -0.013163          -0.119083         -0.975415
# 2           0.275485          -0.026050          -0.118152         -0.993819
# 3           0.270298          -0.032614          -0.117520         -0.994743
# 4           0.274833          -0.027848          -0.129527         -0.993852
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.920091         -0.667683         -0.952501         -0.925249
# 1         -0.967458         -0.944958         -0.986799         -0.968401
# 2         -0.969926         -0.962748         -0.994403         -0.970735
# 3         -0.973268         -0.967091         -0.995274         -0.974471
# 4         -0.967445         -0.978295         -0.994111         -0.965953
#
# ...

# %%
train_df.columns
# Out:
# Index(['tBodyAcc-mean()-X', 'tBodyAcc-mean()-Y', 'tBodyAcc-mean()-Z',
#        'tBodyAcc-std()-X', 'tBodyAcc-std()-Y', 'tBodyAcc-std()-Z',
#        'tBodyAcc-mad()-X', 'tBodyAcc-mad()-Y', 'tBodyAcc-mad()-Z',
#        'tBodyAcc-max()-X',
#        ...
#        'fBodyBodyGyroJerkMag-kurtosis()', 'angle(tBodyAccMean,gravity)',
#        'angle(tBodyAccJerkMean),gravityMean)',
#        'angle(tBodyGyroMean,gravityMean)',
#        'angle(tBodyGyroJerkMean,gravityMean)', 'angle(X,gravityMean)',
#        'angle(Y,gravityMean)', 'angle(Z,gravityMean)', 'subject', 'Activity'],
#       dtype='object', length=563)

# %%
train_df.describe()
# Out:
#        tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# count        7352.000000        7352.000000        7352.000000
# mean            0.274488          -0.017695          -0.109141
# std             0.070261           0.040811           0.056635
# min            -1.000000          -1.000000          -1.000000
# 25%             0.262975          -0.024863          -0.120993
# 50%             0.277193          -0.017219          -0.108676
# 75%             0.288461          -0.010783          -0.097794
# max             1.000000           1.000000           1.000000
#
#        tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# count       7352.000000       7352.000000       7352.000000       7352.000000
# mean          -0.605438         -0.510938         -0.604754         -0.630512
# std            0.448734          0.502645          0.418687          0.424073
# min           -1.000000         -0.999873         -1.000000         -1.000000
# ...

# %%
train_df['Activity'].unique()
# Out:
# array(['STANDING', 'SITTING', 'LAYING', 'WALKING', 'WALKING_DOWNSTAIRS',
#        'WALKING_UPSTAIRS'], dtype=object)

# %%
train_df['Activity'].value_counts().sort_values().plot(kind='bar')

# %% [markdown]
# ### Creating test and train data

# %%
x_train, y_train = train_df.iloc[ : , :-2], train_df.iloc[ : , -1:]
x_train.shape, y_train.shape
# Out:
# ((7352, 561), (7352, 1))

# %%
x_test , y_test = test_df.iloc[ : , :-2],test_df.iloc[ : , -1:]
x_test.shape , y_test.shape
# Out:
# ((2947, 561), (2947, 1))

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y_train = le.fit_transform(y_train)
y_test = le.fit_transform(y_test)
# Out:
# D:\anaconda\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)

# %%
x_test.shape , y_test.shape, x_train.shape , y_train.shape
# Out:
# ((2947, 561), (2947,), (7352, 561), (7352,))

# %%
from sklearn.preprocessing import MinMaxScaler
scaling_data = MinMaxScaler()
x_train = scaling_data.fit_transform(x_train)
x_test = scaling_data.fit_transform(x_test)

# %% [markdown]
# ### Base model

# %%
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout
from kerastuner.tuners import RandomSearch
# Out:
# <ipython-input-16-52814d0f1de2>:5: DeprecationWarning: `import kerastuner` is deprecated, please use `import keras_tuner`.
#   from kerastuner.tuners import RandomSearch

# %%
model = Sequential()
model.add(Dense(units = 64,kernel_initializer='normal',activation='sigmoid',input_dim=x_train.shape[1]))
model.add(Dropout(0.2))
model.add(Dense(units=6, kernel_initializer='normal', activation='softmax'))
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy',metrics=['accuracy'])
history = model.fit(x_train, y_train, batch_size=64, epochs=10,  validation_data=(x_test,y_test))
# Out:
# Epoch 1/10
# 115/115 [==============================] - 2s 8ms/step - loss: 1.3021 - accuracy: 0.4823 - val_loss: 1.0331 - val_accuracy: 0.6620
# Epoch 2/10
# 115/115 [==============================] - 1s 5ms/step - loss: 0.8871 - accuracy: 0.7252 - val_loss: 0.7469 - val_accuracy: 0.7570
# Epoch 3/10
# 115/115 [==============================] - 0s 3ms/step - loss: 0.6299 - accuracy: 0.8164 - val_loss: 0.5599 - val_accuracy: 0.8256
# Epoch 4/10
# 115/115 [==============================] - 0s 3ms/step - loss: 0.4852 - accuracy: 0.8509 - val_loss: 0.4811 - val_accuracy: 0.8364
# Epoch 5/10
# 115/115 [==============================] - 0s 4ms/step - loss: 0.3949 - accuracy: 0.8821 - val_loss: 0.4602 - val_accuracy: 0.8232
# Epoch 6/10
# 115/115 [==============================] - 0s 3ms/step - loss: 0.3391 - accuracy: 0.8901 - val_loss: 0.3640 - val_accuracy: 0.8778
# Epoch 7/10
# ...

# %% [markdown]
# ### Hypertuning the parameters

# %%
def build_model(hp):
    model= Sequential()
    for i in range(hp.Int('num_layers',2,25)):
        model.add(layers.Dense(units=hp.Int('units' + str(i), min_value=32, max_value=512, step=32),
                              kernel_initializer = hp.Choice("initializer", ['uniform', 'normal']),
                              activation =hp.Choice('activation',['relu','sigmoid', 'tanh'])))
        model.add(layers.Dense(units=6, kernel_initializer = hp.Choice('initializer',['uniform','normal']), activation='softmax'))
        model.add(Dropout(0.2))
        model.compile(optimizer = 'adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
        return model
    
    

tuner = RandomSearch(
                     build_model, 
                     objective='val_accuracy',
                     max_trials=5, 
                     executions_per_trial=3,
                     directory='project', project_name = 'Human_activity_recognition') 
tuner.search_space_summary()
# Out:
# INFO:tensorflow:Reloading Oracle from existing project project\Human_activity_recognition\oracle.json
# INFO:tensorflow:Reloading Tuner from project\Human_activity_recognition\tuner0.json
# Search space summary
# Default search space size: 4
# num_layers (Int)
# {'default': None, 'conditions': [], 'min_value': 2, 'max_value': 25, 'step': 1, 'sampling': None}
# units0 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': None}
# initializer (Choice)
# {'default': 'uniform', 'conditions': [], 'values': ['uniform', 'normal'], 'ordered': False}
# activation (Choice)
# {'default': 'relu', 'conditions': [], 'values': ['relu', 'sigmoid', 'tanh'], 'ordered': False}

# %%
tuner.search(x_train, y_train,
             epochs= 10,
             validation_data=(x_test, y_test))
# Out:
# INFO:tensorflow:Oracle triggered exit

# %%
tuner.results_summary()
# Out:
# Results summary
# Results in project\Human_activity_recognition
# Showing 10 best trials
# Objective(name='val_accuracy', direction='max')
# Trial summary
# Hyperparameters:
# num_layers: 13
# units0: 448
# initializer: uniform
# activation: relu
# Score: 0.9148286382357279
# Trial summary
# Hyperparameters:
# num_layers: 6
# units0: 384
# initializer: uniform
# activation: sigmoid
# Score: 0.907476524511973
# Trial summary
# Hyperparameters:
# num_layers: 12
# units0: 64
# initializer: uniform
# activation: tanh
# Score: 0.907024105389913
# Trial summary
# Hyperparameters:
# num_layers: 19
# units0: 480
# initializer: uniform
# activation: tanh
# Score: 0.9066847761472067
# Trial summary
# Hyperparameters:
# num_layers: 18
# units0: 64
# initializer: uniform
# activation: relu
# Score: 0.8932247559229533

# %%
model = tuner.get_best_models(num_models=1)[0]
history = model.fit(x_train,y_train, epochs=51, validation_data=(x_test,y_test))
# Out:
# Epoch 1/51
# 230/230 [==============================] - 2s 6ms/step - loss: 0.7269 - accuracy: 0.7792 - val_loss: 1.3834 - val_accuracy: 0.8426
# Epoch 2/51
# 230/230 [==============================] - 1s 6ms/step - loss: 0.7342 - accuracy: 0.7805 - val_loss: 2.3833 - val_accuracy: 0.7652
# Epoch 3/51
# 230/230 [==============================] - 1s 6ms/step - loss: 0.7117 - accuracy: 0.7735 - val_loss: 1.1056 - val_accuracy: 0.8700
# Epoch 4/51
# 230/230 [==============================] - 1s 5ms/step - loss: 0.6934 - accuracy: 0.7797 - val_loss: 0.8019 - val_accuracy: 0.9002
# Epoch 5/51
# 230/230 [==============================] - 1s 6ms/step - loss: 0.6651 - accuracy: 0.7825 - val_loss: 1.8908 - val_accuracy: 0.8107
# Epoch 6/51
# 230/230 [==============================] - 1s 6ms/step - loss: 0.7093 - accuracy: 0.7765 - val_loss: 0.6533 - val_accuracy: 0.9230
# Epoch 7/51
# ...

# %%
model.summary()
import tensorflow as tf

earlystopping =tf.keras.callbacks.EarlyStopping(monitor='accuracy', patience=3)

model_fit = model.fit(x_train, y_train, epochs=200, validation_data=(x_test,y_test), callbacks=[earlystopping] )
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 448)               251776
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 2694
# _________________________________________________________________
# dropout (Dropout)            (None, 6)                 0
# ...
# Total params: 254,470
# Trainable params: 254,470
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 230/230 [==============================] - 1s 6ms/step - loss: 0.5426 - accuracy: 0.7957 - val_loss: 2.8061 - val_accuracy: 0.7825
# Epoch 2/200
# 230/230 [==============================] - 1s 6ms/step - loss: 0.5213 - accuracy: 0.7942 - val_loss: 0.6938 - val_accuracy: 0.9291
# Epoch 3/200
# ...
