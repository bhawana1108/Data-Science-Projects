# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
red_df = pd.read_csv(r'D:\Projects\Wine Quality\wineQualityReds.csv')

# %%
red_df.head()
# Out:
#    Unnamed: 0  fixed.acidity  volatile.acidity  citric.acid  residual.sugar  \
# 0           1            7.4              0.70         0.00             1.9
# 1           2            7.8              0.88         0.00             2.6
# 2           3            7.8              0.76         0.04             2.3
# 3           4           11.2              0.28         0.56             1.9
# 4           5            7.4              0.70         0.00             1.9
#
#    chlorides  free.sulfur.dioxide  total.sulfur.dioxide  density    pH  \
# 0      0.076                 11.0                  34.0   0.9978  3.51
# 1      0.098                 25.0                  67.0   0.9968  3.20
# 2      0.092                 15.0                  54.0   0.9970  3.26
# 3      0.075                 17.0                  60.0   0.9980  3.16
# 4      0.076                 11.0                  34.0   0.9978  3.51
#
#    sulphates  alcohol  quality
# 0       0.56      9.4        5
# ...

# %%
red_df.drop(['Unnamed: 0'], axis=1,  inplace=True)

# %%
red_df.head()
# Out:
#    fixed.acidity  volatile.acidity  citric.acid  residual.sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free.sulfur.dioxide  total.sulfur.dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
red_df.shape
# Out:
# (1599, 12)

# %%
red_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed.acidity         1599 non-null   float64
#  1   volatile.acidity      1599 non-null   float64
#  2   citric.acid           1599 non-null   float64
#  3   residual.sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free.sulfur.dioxide   1599 non-null   float64
#  6   total.sulfur.dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
red_df.describe()
# Out:
#        fixed.acidity  volatile.acidity  citric.acid  residual.sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free.sulfur.dioxide  total.sulfur.dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
#checking for duplicate
duplicate =red_df.duplicated()
print(duplicate.sum())
red_df[duplicate]
# Out:
# 240
#       fixed.acidity  volatile.acidity  citric.acid  residual.sugar  chlorides  \
# 4               7.4             0.700         0.00            1.90      0.076
# 11              7.5             0.500         0.36            6.10      0.071
# 27              7.9             0.430         0.21            1.60      0.106
# 40              7.3             0.450         0.36            5.90      0.074
# 65              7.2             0.725         0.05            4.65      0.086
# ...             ...               ...          ...             ...        ...
# 1563            7.2             0.695         0.13            2.00      0.076
# 1564            7.2             0.695         0.13            2.00      0.076
# 1567            7.2             0.695         0.13            2.00      0.076
# 1581            6.2             0.560         0.09            1.70      0.053
# 1596            6.3             0.510         0.13            2.30      0.076
#
# ...

# %%
red_df.hist(bins=25, figsize=(10,10))
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.bar(red_df['quality'], red_df['alcohol'], color='red')
plt.xlabel('quality')
plt.ylabel('alcohol')
plt.show()

# %%
#correlation

plt.figure(figsize=(15,10))
sns.heatmap(red_df.corr(), annot=True, cmap= sns.diverging_palette(220, 20, as_cmap=True))

# %%
#converting the prblm in classification
red_df['good_quality'] = [1 if x>6 else 0 for x in red_df['quality']]

# %%
red_df['good_quality'].value_counts()
# Out:
# 0    1382
# 1     217
# Name: good_quality, dtype: int64

# %%
# declare feature variable and target varibale
X = red_df.drop(['quality', 'good_quality'], axis=1)
y= red_df['good_quality']

# %%
#Standardize the feature variable
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

# %%
# splitting the data 
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=0)

# %%
#lets build the models and see which is best
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report


LR = LogisticRegression()
LR.fit(X_train, y_train)

y_pred1 = LR.predict(X_test)

print(classification_report(y_test, y_pred1))
print('Score:', LR.score(X_test, y_test)*100,'%')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95       290
#            1       0.48      0.40      0.44        30
#
#     accuracy                           0.90       320
#    macro avg       0.71      0.68      0.69       320
# weighted avg       0.90      0.90      0.90       320
#
# Score: 90.3125 %

# %%
from sklearn.tree import DecisionTreeClassifier

DTR = DecisionTreeClassifier(random_state=1)

DTR.fit(X_train, y_train)

y_pred2 = DTR.predict(X_test)

print(classification_report(y_test, y_pred2))
print('Score:', DTR.score(X_test, y_test)*100,'%')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.91      0.94       290
#            1       0.48      0.77      0.59        30
#
#     accuracy                           0.90       320
#    macro avg       0.73      0.84      0.77       320
# weighted avg       0.93      0.90      0.91       320
#
# Score: 90.0 %

# %%
from sklearn.ensemble import RandomForestClassifier

RFC = RandomForestClassifier()

RFC.fit(X_train,y_train)

y_pred3= RFC.predict(X_test)

print(classification_report(y_test, y_pred3))
print('Score:', RFC.score(X_test, y_test)*100,'%')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96       290
#            1       0.67      0.53      0.59        30
#
#     accuracy                           0.93       320
#    macro avg       0.81      0.75      0.78       320
# weighted avg       0.93      0.93      0.93       320
#
# Score: 93.125 %

# %%
from sklearn.ensemble import AdaBoostClassifier

ABC = AdaBoostClassifier()
ABC.fit(X_train,y_train)

y_pred4 = ABC.predict(X_test)

print(classification_report(y_test, y_pred4))
print('Score:',ABC.score(X_test, y_test)*100,'%')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95       290
#            1       0.52      0.43      0.47        30
#
#     accuracy                           0.91       320
#    macro avg       0.73      0.70      0.71       320
# weighted avg       0.90      0.91      0.91       320
#
# Score: 90.9375 %

# %%
from sklearn.ensemble import GradientBoostingClassifier

GBC = GradientBoostingClassifier()
GBC.fit(X_train,y_train)

y_pred5 = GBC.predict(X_test)

print(classification_report(y_test,y_pred5))
print('Score:', GBC.score(X_test, y_test)*100,'%')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95       290
#            1       0.53      0.57      0.55        30
#
#     accuracy                           0.91       320
#    macro avg       0.74      0.76      0.75       320
# weighted avg       0.92      0.91      0.91       320
#
# Score: 91.25 %

# %%
from sklearn.naive_bayes import GaussianNB

GNB = GaussianNB()
GNB.fit(X_train,y_train)

y_pred6= GNB.predict(X_test)
print(classification_report(y_test, y_pred6))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.83      0.90       290
#            1       0.32      0.80      0.46        30
#
#     accuracy                           0.82       320
#    macro avg       0.65      0.81      0.68       320
# weighted avg       0.91      0.82      0.85       320

# %% [markdown]
# #### From above models we can see that Random Forest and Gradient Boosting have high accuracy

# %%
#Feature importance by RandomForestClassifier
feat_importance = pd.Series(RFC.feature_importances_, index=X.columns)
feat_importance.nlargest(25).plot(kind='barh', figsize=(10,10))

# %%
#Feature importance by GradientBoosting
feat_importance = pd.Series(GBC.feature_importances_, index=X.columns)
feat_importance.nlargest(25).plot(kind='barh', figsize=(10,10))

# %%
#comparing the top features
red_df_temp1 = red_df[red_df['good_quality']==1]
red_df_temp1.describe()
# Out:
#        fixed.acidity  volatile.acidity  citric.acid  residual.sugar  \
# count     217.000000        217.000000   217.000000      217.000000
# mean        8.847005          0.405530     0.376498        2.708756
# std         1.999977          0.144963     0.194438        1.363026
# min         4.900000          0.120000     0.000000        1.200000
# 25%         7.400000          0.300000     0.300000        2.000000
# 50%         8.700000          0.370000     0.400000        2.300000
# 75%        10.100000          0.490000     0.490000        2.700000
# max        15.600000          0.915000     0.760000        8.900000
#
#         chlorides  free.sulfur.dioxide  total.sulfur.dioxide     density  \
# count  217.000000           217.000000            217.000000  217.000000
# mean     0.075912            13.981567             34.889401    0.996030
# std      0.028480            10.234615             32.572238    0.002201
# ...

# %%
red_df_temp2 = red_df[red_df['good_quality']==0]
red_df_temp2.describe()
# Out:
#        fixed.acidity  volatile.acidity  citric.acid  residual.sugar  \
# count    1382.000000       1382.000000  1382.000000     1382.000000
# mean        8.236831          0.547022     0.254407        2.512120
# std         1.682726          0.176337     0.189665        1.415778
# min         4.600000          0.160000     0.000000        0.900000
# 25%         7.100000          0.420000     0.082500        1.900000
# 50%         7.800000          0.540000     0.240000        2.200000
# 75%         9.100000          0.650000     0.400000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free.sulfur.dioxide  total.sulfur.dioxide      density  \
# count  1382.000000          1382.000000           1382.000000  1382.000000
# mean      0.089281            16.172214             48.285818     0.996859
# std       0.049113            10.467685             32.585604     0.001808
# ...

# %%
red_df_temp1.head(20)
# Out:
#      fixed.acidity  volatile.acidity  citric.acid  residual.sugar  chlorides  \
# 7              7.3             0.650         0.00             1.2      0.065
# 8              7.8             0.580         0.02             2.0      0.073
# 16             8.5             0.280         0.56             1.8      0.092
# 37             8.1             0.380         0.28             2.1      0.066
# 62             7.5             0.520         0.16             1.9      0.085
# 128            8.0             0.590         0.16             1.8      0.065
# 198            5.4             0.835         0.08             1.2      0.046
# 200            9.6             0.320         0.47             1.4      0.056
# 205           12.8             0.300         0.74             2.6      0.095
# 206           12.8             0.300         0.74             2.6      0.095
# 209           11.0             0.300         0.58             2.1      0.054
# ...

# %%
red_df_temp2.head(20)
# Out:
#     fixed.acidity  volatile.acidity  citric.acid  residual.sugar  chlorides  \
# 0             7.4             0.700         0.00             1.9      0.076
# 1             7.8             0.880         0.00             2.6      0.098
# 2             7.8             0.760         0.04             2.3      0.092
# 3            11.2             0.280         0.56             1.9      0.075
# 4             7.4             0.700         0.00             1.9      0.076
# 5             7.4             0.660         0.00             1.8      0.075
# 6             7.9             0.600         0.06             1.6      0.069
# 9             7.5             0.500         0.36             6.1      0.071
# 10            6.7             0.580         0.08             1.8      0.097
# 11            7.5             0.500         0.36             6.1      0.071
# 12            5.6             0.615         0.00             1.6      0.089
# ...
